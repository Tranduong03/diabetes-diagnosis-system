# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Đường dẫn đến tệp data raw
file_path = "../datasets/raw/diabetes_structured.csv"

# Đọc dữ liệu 
try:
    df = pd.read_csv(file_path)

    # Hiển thị tỷ lệ nhãn ban đầu
    print("📊 Phân bố nhãn trước khi tách:")
    print(df["Outcome"].value_counts())
    print("\nTỷ lệ (normalized):") # Thêm \n cho dễ đọc
    print(df["Outcome"].value_counts(normalize=True))

except FileNotFoundError:
    print(f"Lỗi: Không tìm thấy tệp tại đường dẫn '{file_path}'.")
    print("Vui lòng kiểm tra xem bạn đang chạy mã từ thư mục 'Project_2' hay chưa.")
# Out:
# 📊 Phân bố nhãn trước khi tách:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64
#
# Tỷ lệ (normalized):
# Outcome
# 0    0.651042
# 1    0.348958
# Name: proportion, dtype: float64

# %%
# Tách dữ liệu train/test (80% - 20%)
train_df, test_df = train_test_split(
  df, 
  test_size=0.2, 
  random_state=42, 
  shuffle=True,
  stratify=df['Outcome']  # Giữ tỷ lệ phân phối của nhãn 'Outcome'
)

# Hiển thị tỷ lệ nhãn sau khi tách
print("\n📊 Phân bố nhãn trong tập train:")
print(train_df["Outcome"].value_counts())
print(train_df["Outcome"].value_counts(normalize=True))

print("\n📊 Phân bố nhãn trong tập test:")
print(test_df["Outcome"].value_counts())
print(test_df["Outcome"].value_counts(normalize=True))
# Out:
# 📊 Phân bố nhãn trong tập train:
# Outcome
# 0    400
# 1    214
# Name: count, dtype: int64
# Outcome
# 0    0.651466
# 1    0.348534
# Name: proportion, dtype: float64
#
# 📊 Phân bố nhãn trong tập test:
# Outcome
# 0    100
# 1     54
# Name: count, dtype: int64
# Outcome
# 0    0.649351
# 1    0.350649
# Name: proportion, dtype: float64

# %%
# Đường dẫn lưu file
train_path = r"..\datasets\processed\train_data.csv"
test_path = r"..\datasets\processed\test_data.csv"

# Lưu ra file CSV
train_df.to_csv(train_path, index=False)
test_df.to_csv(test_path, index=False)

# %%
print("✅ Đã tách dữ liệu thành công!")
print(f"Kích thước tập train: {train_df.shape}")
print(f"Kích thước tập test: {test_df.shape}")
# Out:
# ✅ Đã tách dữ liệu thành công!
# Kích thước tập train: (614, 9)
# Kích thước tập test: (154, 9)
